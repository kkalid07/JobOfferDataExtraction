# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import random

# Charger le dataset (fichier CSV avec séparateur ';')
file_path = "Jobopportunities.xlsx"
df = pd.read_excel(file_path)

# Garder uniquement les colonnes nécessaires et créer une copie explicite
df_filtered = df[['Job Title', 'Company']].copy()

# Ajouter une colonne 'Text' avec un texte plus complexe
def generate_text(row):
    job_title = row["Job Title"]
    company_name = row["Company"]

    # Générer une description plus complexe avec des variantes
    templates = [
        f"{job_title} needed at {company_name}! Join our dynamic team to achieve great things together.",
        f"Exciting opportunity: {job_title} position open at {company_name}. Seize your chance today!",
        f"{company_name} is seeking a passionate {job_title} to innovate and grow with us.",
        f"Are you a skilled {job_title}? {company_name} wants you on board! Apply now and be part of our journey.",
        f"{company_name} has an urgent opening for a {job_title}. Shape the future with us—apply today!",
        f"Looking for your next challenge? {company_name} is hiring a talented {job_title}. Don't miss out!"
    ]
    return random.choice(templates)

df_filtered['Text'] = df_filtered.apply(generate_text, axis=1)


# Sauvegarder le résultat dans un nouveau fichier CSV
output_path = "Finalfiltered_job_data_complex.csv"
df_filtered.to_csv(output_path, index=False, sep=';')

# Afficher un aperçu
print(df_filtered.head())
# Out:
#                Job Title            Company  \
# 0      Software Engineer           ABC Tech
# 1           Data Analyst      XYZ Analytics
# 2       Network Engineer  Network Solutions
# 3        Cloud Architect   Cloud Innovators
# 4  Cybersecurity Analyst        SecureGuard
#
#                                                 Text
# 0  Are you a skilled Software Engineer? ABC Tech ...
# 1  Data Analyst needed at XYZ Analytics! Join our...
# 2  Network Engineer needed at Network Solutions! ...
# 3  Cloud Architect needed at Cloud Innovators! Jo...
# 4  Exciting opportunity: Cybersecurity Analyst po...

# %%
import pandas as pd
import random

# Charger le dataset (fichier CSV avec séparateur ';')
file_path = "organized_job_data_semicolon.csv"
df = pd.read_csv(file_path, sep=';')

# Garder uniquement les colonnes nécessaires et créer une copie explicite
df_filtered = df[['Job Title', 'Company Name']].copy()

# Ajouter une colonne 'Text' avec un texte plus complexe
def generate_text(row):
    job_title = row["Job Title"]
    company_name = row["Company Name"]

    # Générer une description plus complexe avec des variantes
    templates = [
        f"{job_title} needed at {company_name}! Join our dynamic team to achieve great things together.",
        f"Exciting opportunity: {job_title} position open at {company_name}. Seize your chance today!",
        f"{company_name} is seeking a passionate {job_title} to innovate and grow with us.",
        f"Are you a skilled {job_title}? {company_name} wants you on board! Apply now and be part of our journey.",
        f"{company_name} has an urgent opening for a {job_title}. Shape the future with us—apply today!",
        f"Looking for your next challenge? {company_name} is hiring a talented {job_title}. Don't miss out!"
    ]
    return random.choice(templates)

df_filtered['Text'] = df_filtered.apply(generate_text, axis=1)



# Sauvegarder le résultat dans un nouveau fichier CSV
output_path = "filtered_job_data_complex_updated.csv"
df_filtered.to_csv(output_path, index=False, sep=';')

# Afficher un aperçu
print(df_filtered.head())
# Out:
#                        Job Title                   Company Name  \
# 0   développeur symfony confirmé                       OCTASOFT
# 1                  Sales Manager  United HR Solutions Pvt. Ltd.
# 2      Human Resources Recruiter      BDNT Labs Private Limited
# 3  Back-End Management Executive                 Suprem Service
# 4             Back-End Executive                 Suprem Service
#
#                                                 Text
# 0  OCTASOFT has an urgent opening for a développe...
# 1  Exciting opportunity: Sales Manager position o...
# 2  BDNT Labs Private Limited has an urgent openin...
# 3  Suprem Service has an urgent opening for a Bac...
# 4  Back-End Executive needed at Suprem Service! J...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from joblib import Memory
import pickle

# Load data
data = pd.read_csv("Finalfiltered_job_data_complex.csv", sep=";")
data = data.dropna(subset=["Job Title", "Company", "Text"])

# Parameters for TfidfVectorizer
vectorizer_params = {
    "stop_words": "english",
    "ngram_range": (1, 2),
    "lowercase": True,
    "min_df": 5,  # Ignore terms appearing in fewer than 5 documents
}

# Memory caching for the TF-IDF Vectorizer
memory = Memory("./cache", verbose=0)

# Function to train and evaluate a model using cross-validation
def train_and_evaluate_model_cv(X, y, model_name, n_splits=5):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold = 1
    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Define pipeline
        pipeline = Pipeline([
            ("vectorizer", memory.cache(TfidfVectorizer)(**vectorizer_params)),
            ("classifier", GradientBoostingClassifier(
                n_estimators=100,  # Slightly more trees for better accuracy
                max_depth=5,  # Limit depth to reduce computation
                subsample=0.9,  # Use 80% of data for each tree
                random_state=42
            ))
        ])

        # Training
        pipeline.fit(X_train, y_train)

        # Evaluate performance
        y_pred = pipeline.predict(X_test)
        print(f"{model_name} Classification Report for fold {fold}:")
        print(classification_report(y_test, y_pred, zero_division=0))
        fold += 1

    # Save the final model trained on the whole dataset
    pipeline.fit(X, y)
    model_file = f"{model_name.lower().replace(' ', '_')}_FFFfinalmodel.pkl"
    with open(model_file, "wb") as file:
        pickle.dump(pipeline, file)

    print(f"{model_name} final model saved to {model_file}")
    return pipeline

# Train models using cross-validation
job_title_model = train_and_evaluate_model_cv(data["Text"].values, data["Job Title"].values, "Job Title")
company_name_model = train_and_evaluate_model_cv(data["Text"].values, data["Company"].values, "Company Name")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Job Title Classification Report for fold 1:
#                                     precision    recall  f1-score   support
#
#               AI Ethics Consultant       1.00      1.00      1.00         2
#                     AI/ML Engineer       1.00      1.00      1.00         1
#               Blockchain Developer       1.00      1.00      1.00         2
#                    Cloud Architect       1.00      1.00      1.00         2
#             Cloud Security Analyst       0.00      0.00      0.00         0
#            Cloud Security Engineer       1.00      1.00      1.00         1
#            Cloud Solutions Analyst       1.00      1.00      1.00         3
#          Cloud Solutions Architect       0.00      0.00      0.00         1
#             Cloud Solutions Intern       0.00      0.00      0.00         1
#             Cloud Support Engineer       1.00      1.00      1.00         1
#              Cybersecurity Analyst       1.00      1.00      1.00         1
#             Cybersecurity Engineer       1.00      1.00      1.00         1
#                       Data Analyst       1.00      1.00      1.00         4
#             Data Analytics Manager       1.00      1.00      1.00         1
#                      Data Engineer       1.00      1.00      1.00         2
#            Data Governance Analyst       0.00      0.00      0.00         0
#               Data Privacy Officer       1.00      1.00      1.00         1
#                     Data Scientist       1.00      1.00      1.00         2
#             Database Administrator       1.00      1.00      1.00         1
#                   Database Analyst       1.00      1.00      1.00         1
#                    DevOps Engineer       1.00      1.00      1.00         2
#                 DevSecOps Engineer       0.00      0.00      0.00         1
#                Front-end Developer       1.00      1.00      1.00         1
#               Full-stack Developer       1.00      1.00      1.00         2
#                 IT Analyst Trainee       0.00      0.00      0.00         1
#                         IT Auditor       1.00      1.00      1.00         1
#                IT Business Analyst       1.00      1.00      1.00         1
#              IT Compliance Officer       1.00      1.00      1.00         2
#                      IT Consultant       1.00      1.00      1.00         1
#              IT Governance Manager       0.00      0.00      0.00         1
#                IT Helpdesk Support       0.00      0.00      0.00         1
#             IT Procurement Manager       1.00      1.00      1.00         1
#          IT Procurement Specialist       1.00      1.00      1.00         1
#             IT Project Coordinator       1.00      1.00      1.00         1
#                 IT Project Manager       1.00      1.00      1.00         2
#                 IT Quality Analyst       0.50      1.00      0.67         1
#                    IT Risk Analyst       0.00      0.00      0.00         1
#                   IT Sales Manager       1.00      1.00      1.00         1
#             IT Security Consultant       0.00      0.00      0.00         1
#            IT Service Desk Analyst       0.00      0.00      0.00         0
#              IT Support Specialist       0.38      1.00      0.55         3
#                         IT Trainer       1.00      1.00      1.00         1
#               Mobile App Developer       1.00      1.00      1.00         1
#                   Network Engineer       1.00      1.00      1.00         2
#          Network Security Engineer       1.00      1.00      1.00         1
#             QA Automation Engineer       0.00      0.00      0.00         1
# Senior Front-end Angular Developer       1.00      1.00      1.00         3
#                 Software Architect       1.00      1.00      1.00         2
#                 Software Developer       1.00      1.00      1.00         1
#                    Software Tester       1.00      1.00      1.00         1
#                  Symfony Developer       0.67      1.00      0.80         2
#               System Administrator       0.00      0.00      0.00         1
#                        UX Designer       1.00      1.00      1.00         2
#                      UX Researcher       1.00      1.00      1.00         1
#
#                           accuracy                           0.86        73
#                          macro avg       0.73      0.76      0.74        73
#                       weighted avg       0.82      0.86      0.83        73
#
# Job Title Classification Report for fold 2:
#                                     precision    recall  f1-score   support
#
#               AI Ethics Consultant       1.00      1.00      1.00         2
#                     AI/ML Engineer       1.00      1.00      1.00         1
#               Blockchain Developer       1.00      1.00      1.00         2
#                    Cloud Architect       1.00      1.00      1.00         1
#            Cloud Security Engineer       1.00      1.00      1.00         2
#            Cloud Solutions Analyst       1.00      1.00      1.00         3
#          Cloud Solutions Architect       1.00      1.00      1.00         1
#             Cloud Support Engineer       1.00      1.00      1.00         1
#              Cybersecurity Analyst       1.00      1.00      1.00         2
#                       Data Analyst       0.80      1.00      0.89         4
#                Data Analyst Intern       0.00      0.00      0.00         1
#             Data Analytics Manager       1.00      1.00      1.00         1
#                      Data Engineer       1.00      1.00      1.00         1
#            Data Governance Analyst       0.00      0.00      0.00         1
#               Data Privacy Officer       1.00      1.00      1.00         1
#                     Data Scientist       1.00      1.00      1.00         2
#                   Database Analyst       1.00      1.00      1.00         1
#                    DevOps Engineer       1.00      1.00      1.00         1
#                 DevSecOps Engineer       1.00      1.00      1.00         1
#                Front-end Developer       0.50      1.00      0.67         1
#               Full-stack Developer       1.00      1.00      1.00         2
#                         IT Auditor       1.00      1.00      1.00         1
#                IT Business Analyst       1.00      1.00      1.00         1
#     IT Business Continuity Manager       0.00      0.00      0.00         0
#                  IT Change Manager       0.00      0.00      0.00         1
#              IT Compliance Officer       1.00      1.00      1.00         2
#                      IT Consultant       1.00      1.00      1.00         1
#              IT Governance Manager       0.50      1.00      0.67         1
#                IT Helpdesk Support       0.00      0.00      0.00         1
#             IT Procurement Analyst       1.00      1.00      1.00         1
#             IT Procurement Manager       1.00      1.00      1.00         1
#             IT Project Coordinator       1.00      1.00      1.00         1
#                 IT Project Manager       1.00      1.00      1.00         2
#                 IT Quality Analyst       1.00      1.00      1.00         1
#                    IT Risk Analyst       1.00      1.00      1.00         1
#                   IT Sales Manager       1.00      1.00      1.00         2
#                IT Security Analyst       1.00      1.00      1.00         1
#              IT Support Specialist       1.00      1.00      1.00         3
#                         IT Trainer       0.00      0.00      0.00         1
#               IT Trainer Assistant       0.00      0.00      0.00         0
#               Mobile App Developer       1.00      1.00      1.00         1
#                   Network Engineer       1.00      1.00      1.00         2
#          Network Security Engineer       1.00      1.00      1.00         1
# Senior Front-end Angular Developer       0.67      0.67      0.67         3
#                 Software Architect       1.00      1.00      1.00         2
#                 Software Developer       1.00      1.00      1.00         2
#                    Software Tester       1.00      1.00      1.00         1
#                  Symfony Developer       1.00      1.00      1.00         2
#               System Administrator       1.00      1.00      1.00         1
#                        UX Designer       0.50      1.00      0.67         1
#              UX Research Assistant       0.00      0.00      0.00         1
#                      UX Researcher       1.00      1.00      1.00         1
#                     UX/UI Designer       1.00      1.00      1.00         1
#
#                           accuracy                           0.90        73
#                          macro avg       0.81      0.84      0.82        73
#                       weighted avg       0.87      0.90      0.88        73
#
# Job Title Classification Report for fold 3:
#                                     precision    recall  f1-score   support
#
#               AI Ethics Consultant       1.00      1.00      1.00         1
#                     AI/ML Engineer       1.00      1.00      1.00         1
#               Blockchain Developer       1.00      1.00      1.00         1
#                    Cloud Architect       1.00      1.00      1.00         1
#            Cloud Security Engineer       1.00      1.00      1.00         2
#            Cloud Solutions Analyst       1.00      1.00      1.00         2
#          Cloud Solutions Architect       1.00      1.00      1.00         1
#             Cloud Support Engineer       1.00      1.00      1.00         2
#              Cybersecurity Analyst       1.00      1.00      1.00         2
#                       Data Analyst       0.67      1.00      0.80         4
#             Data Analytics Manager       1.00      1.00      1.00         2
#                      Data Engineer       1.00      1.00      1.00         1
#               Data Privacy Officer       1.00      1.00      1.00         1
#                     Data Scientist       1.00      1.00      1.00         2
#             Database Administrator       1.00      1.00      1.00         1
#                    DevOps Engineer       1.00      1.00      1.00         1
#                 DevSecOps Engineer       0.00      0.00      0.00         1
#                Front-end Developer       1.00      1.00      1.00         1
#               Full-stack Developer       1.00      1.00      1.00         3
#                         IT Auditor       1.00      1.00      1.00         1
#                IT Business Analyst       1.00      1.00      1.00         1
#              IT Compliance Officer       0.50      1.00      0.67         1
#           IT Compliance Specialist       0.00      0.00      0.00         1
#                      IT Consultant       1.00      1.00      1.00         1
#              IT Governance Manager       1.00      1.00      1.00         2
#                IT Helpdesk Support       0.00      0.00      0.00         0
#             IT Procurement Analyst       1.00      1.00      1.00         1
#             IT Procurement Manager       1.00      1.00      1.00         1
#          IT Procurement Specialist       1.00      1.00      1.00         1
#             IT Project Coordinator       1.00      1.00      1.00         1
#                 IT Project Manager       1.00      1.00      1.00         1
#                 IT Quality Analyst       1.00      1.00      1.00         2
#                    IT Risk Analyst       1.00      1.00      1.00         1
#                   IT Sales Manager       0.50      1.00      0.67         1
#            IT Sales Representative       0.00      0.00      0.00         1
#                IT Security Analyst       1.00      1.00      1.00         1
#            IT Service Desk Analyst       0.00      0.00      0.00         1
#                 IT Support Analyst       0.00      0.00      0.00         1
#              IT Support Specialist       1.00      1.00      1.00         3
#                         IT Trainer       0.50      1.00      0.67         1
#              IT Trainer Specialist       0.00      0.00      0.00         1
#               Mobile App Developer       1.00      1.00      1.00         2
#                   Network Engineer       1.00      1.00      1.00         1
#          Network Security Engineer       1.00      1.00      1.00         1
# Senior Front-end Angular Developer       1.00      1.00      1.00         3
#                 Software Architect       1.00      1.00      1.00         1
#                 Software Developer       1.00      1.00      1.00         2
#                  Software Engineer       0.00      0.00      0.00         0
#                    Software Tester       1.00      1.00      1.00         1
#                  Symfony Developer       1.00      1.00      1.00         2
#               System Administrator       0.00      0.00      0.00         1
#                       UI Developer       1.00      1.00      1.00         1
#                        UX Designer       1.00      1.00      1.00         1
#                      UX Researcher       1.00      1.00      1.00         1
#                     UX/UI Designer       1.00      1.00      1.00         1
#
#                           accuracy                           0.90        73
#                          macro avg       0.80      0.84      0.81        73
#                       weighted avg       0.87      0.90      0.88        73
#
# Job Title Classification Report for fold 4:
#                                     precision    recall  f1-score   support
#
#               AI Ethics Consultant       1.00      1.00      1.00         1
#                     AI/ML Engineer       0.67      1.00      0.80         2
#               Blockchain Developer       1.00      1.00      1.00         1
#                   Business Analyst       0.00      0.00      0.00         1
#                    Cloud Architect       1.00      1.00      1.00         2
#         Cloud Migration Specialist       0.00      0.00      0.00         1
#             Cloud Security Analyst       0.00      0.00      0.00         1
#            Cloud Security Engineer       0.50      1.00      0.67         1
#            Cloud Solutions Analyst       1.00      1.00      1.00         2
#          Cloud Solutions Architect       1.00      1.00      1.00         1
#             Cloud Support Engineer       1.00      1.00      1.00         2
#              Cybersecurity Analyst       1.00      1.00      1.00         2
#             Cybersecurity Engineer       1.00      1.00      1.00         1
#                       Data Analyst       0.57      1.00      0.73         4
#             Data Analytics Manager       1.00      1.00      1.00         2
#                      Data Engineer       1.00      1.00      1.00         2
#               Data Privacy Officer       1.00      1.00      1.00         1
#                     Data Scientist       1.00      1.00      1.00         2
#             Database Administrator       0.00      0.00      0.00         1
#                    DevOps Engineer       1.00      1.00      1.00         1
#                Front-end Developer       1.00      1.00      1.00         1
#               Full-stack Developer       1.00      1.00      1.00         3
#                         IT Analyst       0.00      0.00      0.00         1
#                IT Business Analyst       1.00      1.00      1.00         1
#     IT Business Continuity Manager       0.00      0.00      0.00         0
#              IT Compliance Officer       1.00      1.00      1.00         1
#                      IT Consultant       1.00      1.00      1.00         1
#              IT Governance Manager       1.00      1.00      1.00         1
#             IT Procurement Analyst       1.00      1.00      1.00         1
#             IT Procurement Manager       1.00      1.00      1.00         1
#          IT Procurement Specialist       1.00      1.00      1.00         1
#             IT Project Coordinator       1.00      1.00      1.00         1
#                 IT Project Manager       1.00      1.00      1.00         1
#                 IT Quality Analyst       1.00      1.00      1.00         1
#                    IT Risk Analyst       1.00      1.00      1.00         1
#                   IT Sales Manager       1.00      1.00      1.00         1
#                IT Security Analyst       0.33      1.00      0.50         1
#                 IT Support Analyst       0.00      0.00      0.00         1
#              IT Support Specialist       1.00      1.00      1.00         3
#                         IT Trainer       0.50      1.00      0.67         1
#               IT Trainer Assistant       0.00      0.00      0.00         1
#          Machine Learning Engineer       0.00      0.00      0.00         1
#               Mobile App Developer       1.00      1.00      1.00         2
#                   Network Engineer       1.00      1.00      1.00         1
# Senior Front-end Angular Developer       1.00      1.00      1.00         2
#                 Software Architect       1.00      1.00      1.00         1
#                 Software Developer       1.00      1.00      1.00         1
#        Software Development Intern       0.00      0.00      0.00         1
#                    Software Tester       1.00      1.00      1.00         2
#                  Symfony Developer       1.00      1.00      1.00         2
#                       UI Developer       1.00      1.00      1.00         1
#                        UX Designer       1.00      1.00      1.00         1
#                      UX Researcher       1.00      1.00      1.00         2
#                     UX/UI Designer       1.00      1.00      1.00         1
#
#                           accuracy                           0.88        73
#                          macro avg       0.77      0.81      0.78        73
#                       weighted avg       0.82      0.88      0.84        73
#
# Job Title Classification Report for fold 5:
#                                     precision    recall  f1-score   support
#
#               AI Ethics Consultant       1.00      1.00      1.00         1
#                     AI/ML Engineer       1.00      1.00      1.00         2
#               Blockchain Developer       1.00      1.00      1.00         1
#                   Business Analyst       0.00      0.00      0.00         1
#                    Cloud Architect       1.00      1.00      1.00         2
#            Cloud Security Engineer       1.00      1.00      1.00         1
#            Cloud Solutions Analyst       1.00      1.00      1.00         2
#             Cloud Support Engineer       1.00      1.00      1.00         1
#              Cybersecurity Analyst       1.00      1.00      1.00         2
#             Cybersecurity Engineer       0.50      1.00      0.67         1
#                       Data Analyst       1.00      0.75      0.86         4
#             Data Analytics Manager       1.00      1.00      1.00         1
#                      Data Engineer       1.00      0.50      0.67         2
#               Data Privacy Officer       1.00      1.00      1.00         2
#                     Data Scientist       1.00      1.00      1.00         1
#             Database Administrator       0.50      1.00      0.67         1
#                   Database Analyst       0.00      0.00      0.00         1
#                    DevOps Engineer       1.00      1.00      1.00         2
#                Front-end Developer       1.00      1.00      1.00         2
#               Full-stack Developer       1.00      1.00      1.00         2
#                   IT Asset Manager       0.00      0.00      0.00         1
#                         IT Auditor       1.00      1.00      1.00         1
#                IT Business Analyst       0.67      1.00      0.80         2
#     IT Business Continuity Manager       0.00      0.00      0.00         1
#              IT Compliance Officer       1.00      1.00      1.00         1
#                      IT Consultant       0.00      0.00      0.00         1
#              IT Governance Manager       1.00      1.00      1.00         1
#             IT Procurement Analyst       0.00      0.00      0.00         0
#         IT Procurement Coordinator       0.00      0.00      0.00         1
#             IT Procurement Manager       1.00      1.00      1.00         2
#          IT Procurement Specialist       0.50      1.00      0.67         1
#             IT Project Coordinator       1.00      1.00      1.00         2
#                 IT Project Manager       1.00      1.00      1.00         2
#                 IT Quality Analyst       1.00      1.00      1.00         1
#                    IT Risk Analyst       0.00      0.00      0.00         1
#                   IT Sales Manager       1.00      1.00      1.00         1
#                IT Security Analyst       0.00      0.00      0.00         1
#              IT Support Specialist       1.00      1.00      1.00         3
#                         IT Trainer       0.50      1.00      0.67         1
#               Mobile App Developer       1.00      1.00      1.00         1
#      Network Administrator Trainee       0.00      0.00      0.00         1
#                   Network Engineer       0.50      1.00      0.67         1
# Senior Front-end Angular Developer       1.00      1.00      1.00         2
#                 Software Architect       1.00      1.00      1.00         1
#                 Software Developer       1.00      1.00      1.00         1
#                  Software Engineer       0.00      0.00      0.00         1
#                    Software Tester       1.00      1.00      1.00         2
#                  Symfony Developer       1.00      1.00      1.00         2
#                       UI Developer       1.00      1.00      1.00         1
#                        UX Designer       1.00      1.00      1.00         2
#                      UX Researcher       1.00      1.00      1.00         2
#
#                           accuracy                           0.84        73
#                          macro avg       0.73      0.77      0.74        73
#                       weighted avg       0.82      0.84      0.82        73
#
# Job Title final model saved to job_title_FFFfinalmodel.pkl
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Company Name Classification Report for fold 1:
#                           precision    recall  f1-score   support
#
#                AI Ethics       1.00      1.00      1.00         2
#           AI Innovations       1.00      1.00      1.00         1
#           Asset Managers       0.00      0.00      0.00         1
#            Audit Experts       1.00      1.00      1.00         1
#             Biz Analysts       0.00      0.00      0.00         0
#          Blockchain Tech       1.00      1.00      1.00         1
#                      CED       1.00      1.00      1.00         2
#          Change Managers       0.00      0.00      0.00         0
#           Cloud Analysts       1.00      1.00      1.00         3
#         Cloud Architects       0.00      0.00      0.00         1
#        Cloud Innovations       0.00      0.00      0.00         1
#         Cloud Innovators       1.00      1.00      1.00         1
#            Cloud Support       1.00      1.00      1.00         2
#       Compliance Experts       1.00      1.00      1.00         1
#      Continuity Managers       0.00      0.00      0.00         1
#  Cybersecurity Engineers       1.00      1.00      1.00         1
#           Data Engineers       1.00      1.00      1.00         1
#            Data Insights       1.00      1.00      1.00         3
#          Data Management       1.00      1.00      1.00         1
#            Data Managers       1.00      1.00      1.00         1
#             Data Privacy       1.00      1.00      1.00         1
#           Data Solutions       1.00      1.00      1.00         1
#         DevOps Solutions       1.00      1.00      1.00         2
#          Full-stack Devs       1.00      1.00      1.00         1
#              IT Analysts       0.00      0.00      0.00         1
#       IT Governance Mgmt       1.00      1.00      1.00         1
#              IT Helpdesk       0.00      0.00      0.00         1
#             IT Solutions       1.00      1.00      1.00         1
#       IT Support Experts       1.00      1.00      1.00         1
#   IT Support Specialists       1.00      1.00      1.00         1
#              IT Training       1.00      1.00      1.00         1
#              Mobile Devs       1.00      1.00      1.00         2
#   Network Admin Trainees       0.00      0.00      0.00         1
#          Network Experts       0.20      1.00      0.33         1
#                 OCTASOFT       1.00      1.00      1.00         3
#                ProcureIT       1.00      1.00      1.00         1
#     Procurement Analysts       0.00      0.00      0.00         0
# Procurement Coordinators       0.00      0.00      0.00         1
#         Procurement Mgmt       0.00      0.00      0.00         1
#     Project Coordinators       1.00      1.00      1.00         1
#          Project Leaders       1.00      1.00      1.00         2
#              Purecontrol       1.00      1.00      1.00         2
#              QA Analysts       1.00      1.00      1.00         1
#             QA Solutions       1.00      1.00      1.00         1
#            Risk Analysts       1.00      1.00      1.00         1
#            Sales Leaders       1.00      1.00      1.00         1
#            Secure DevOps       0.00      0.00      0.00         1
#              SecureCloud       1.00      1.00      1.00         2
#              SecureGuard       1.00      1.00      1.00         2
#                 SecureIT       1.00      1.00      1.00         1
#                SecureNet       1.00      1.00      1.00         1
#      Software Architects       1.00      1.00      1.00         1
#          System Services       1.00      1.00      1.00         1
#         Tech Innovations       0.00      0.00      0.00         0
#           Tech Solutions       1.00      1.00      1.00         2
#             UX Designers       1.00      1.00      1.00         1
#           UX Innovations       1.00      1.00      1.00         1
#                  UX Labs       1.00      1.00      1.00         1
#            Web Creations       1.00      1.00      1.00         2
#              Web Studios       1.00      1.00      1.00         1
#
#                 accuracy                           0.86        73
#                macro avg       0.75      0.77      0.76        73
#             weighted avg       0.85      0.86      0.85        73
#
# Company Name Classification Report for fold 2:
#                         precision    recall  f1-score   support
#
#              AI Ethics       1.00      1.00      1.00         1
#         AI Innovations       1.00      1.00      1.00         1
#          Audit Experts       1.00      1.00      1.00         1
#        Blockchain Tech       1.00      1.00      1.00         1
#                    CED       1.00      0.50      0.67         2
#         Cloud Analysts       0.60      1.00      0.75         3
#       Cloud Architects       0.00      0.00      0.00         1
#      Cloud Innovations       1.00      1.00      1.00         1
#       Cloud Innovators       0.50      1.00      0.67         1
#          Cloud Interns       0.00      0.00      0.00         1
#         Cloud Security       0.00      0.00      0.00         0
#          Cloud Support       1.00      1.00      1.00         2
#     Compliance Experts       1.00      1.00      1.00         1
#         Data Engineers       1.00      1.00      1.00         1
#          Data Insights       1.00      1.00      1.00         3
#        Data Management       0.00      0.00      0.00         1
#          Data Managers       1.00      1.00      1.00         1
#           Data Privacy       1.00      1.00      1.00         1
#         Data Solutions       0.50      1.00      0.67         1
#       DevOps Solutions       1.00      1.00      1.00         2
#        Full-stack Devs       1.00      1.00      1.00         1
#    IT Analyst Trainees       0.00      0.00      0.00         1
#            IT Analysts       1.00      1.00      1.00         1
#         IT Consultancy       1.00      1.00      1.00         1
#     IT Governance Mgmt       1.00      1.00      1.00         1
#            IT Helpdesk       0.00      0.00      0.00         1
#            IT Services       0.00      0.00      0.00         0
#           IT Solutions       0.00      0.00      0.00         1
#     IT Support Experts       1.00      1.00      1.00         1
# IT Support Specialists       1.00      1.00      1.00         2
#            IT Training       1.00      1.00      1.00         1
#            Mobile Devs       1.00      1.00      1.00         2
#        Network Experts       1.00      1.00      1.00         2
#               OCTASOFT       1.00      1.00      1.00         2
#              ProcureIT       1.00      1.00      1.00         1
#   Procurement Analysts       1.00      1.00      1.00         1
#       Procurement Mgmt       1.00      1.00      1.00         1
#   Project Coordinators       1.00      1.00      1.00         1
#        Project Leaders       1.00      1.00      1.00         2
#            Purecontrol       0.67      1.00      0.80         2
#           Purecontrol        0.00      0.00      0.00         1
#            QA Analysts       1.00      1.00      1.00         1
#          QA Automation       0.00      0.00      0.00         1
#           QA Solutions       1.00      1.00      1.00         1
#          Risk Analysts       1.00      1.00      1.00         1
#          Sales Leaders       1.00      1.00      1.00         1
#          Secure DevOps       1.00      1.00      1.00         1
#            SecureCloud       1.00      1.00      1.00         1
#            SecureGuard       1.00      1.00      1.00         2
#               SecureIT       1.00      1.00      1.00         1
#              SecureNet       1.00      1.00      1.00         1
#   Security Consultants       0.00      0.00      0.00         1
#    Software Architects       1.00      1.00      1.00         1
#        System Services       0.50      1.00      0.67         1
#         Tech Solutions       1.00      1.00      1.00         1
#           UX Designers       0.00      0.00      0.00         1
#         UX Innovations       0.00      0.00      0.00         0
#                UX Labs       1.00      1.00      1.00         2
#          Web Creations       1.00      1.00      1.00         2
#            Web Studios       0.50      1.00      0.67         1
#
#               accuracy                           0.85        73
#              macro avg       0.74      0.78      0.75        73
#           weighted avg       0.81      0.85      0.82        73
#
# Company Name Classification Report for fold 3:
#                         precision    recall  f1-score   support
#
#              AI Ethics       1.00      1.00      1.00         1
#         AI Innovations       1.00      1.00      1.00         1
#          Audit Experts       0.00      0.00      0.00         1
#        Blockchain Tech       1.00      1.00      1.00         1
#                    CED       1.00      1.00      1.00         3
#        Change Managers       0.00      0.00      0.00         1
#         Cloud Analysts       1.00      1.00      1.00         2
#       Cloud Architects       0.33      1.00      0.50         1
#      Cloud Innovations       0.00      0.00      0.00         1
#       Cloud Innovators       0.00      0.00      0.00         1
#          Cloud Support       1.00      1.00      1.00         1
#     Compliance Experts       1.00      1.00      1.00         1
#         Data Engineers       0.67      1.00      0.80         2
#        Data Governance       0.00      0.00      0.00         1
#        Data Innovators       0.00      0.00      0.00         1
#          Data Insights       0.60      1.00      0.75         3
#           Data Interns       0.00      0.00      0.00         1
#        Data Management       0.00      0.00      0.00         0
#          Data Managers       1.00      1.00      1.00         2
#           Data Privacy       1.00      1.00      1.00         2
#         Data Solutions       0.00      0.00      0.00         1
#         Design Studios       1.00      1.00      1.00         1
#       DevOps Solutions       1.00      1.00      1.00         1
#        Full-stack Devs       1.00      1.00      1.00         1
#            IT Analysts       0.50      1.00      0.67         1
#         IT Consultancy       1.00      1.00      1.00         1
#     IT Governance Mgmt       1.00      1.00      1.00         2
#           IT Solutions       1.00      1.00      1.00         1
#     IT Support Experts       1.00      1.00      1.00         1
# IT Support Specialists       1.00      1.00      1.00         1
#            IT Training       1.00      1.00      1.00         1
#            Mobile Devs       1.00      1.00      1.00         1
#        Network Experts       1.00      1.00      1.00         2
#               OCTASOFT       1.00      1.00      1.00         2
#              ProcureIT       1.00      1.00      1.00         1
#   Procurement Analysts       1.00      1.00      1.00         1
#       Procurement Mgmt       1.00      1.00      1.00         2
#   Project Coordinators       1.00      1.00      1.00         1
#        Project Leaders       1.00      1.00      1.00         2
#            Purecontrol       0.67      1.00      0.80         2
#            QA Analysts       1.00      1.00      1.00         1
#           QA Solutions       1.00      1.00      1.00         1
#          Risk Analysts       0.00      0.00      0.00         1
#          Sales Leaders       1.00      1.00      1.00         2
#            SecureCloud       1.00      1.00      1.00         1
#            SecureGuard       1.00      1.00      1.00         2
#               SecureIT       1.00      1.00      1.00         1
#              SecureNet       1.00      1.00      1.00         1
#    Software Architects       1.00      1.00      1.00         1
#        System Services       0.50      1.00      0.67         1
#         Tech Solutions       1.00      1.00      1.00         1
#           UX Designers       0.00      0.00      0.00         0
#         UX Innovations       1.00      1.00      1.00         1
#                UX Labs       1.00      1.00      1.00         2
# UX Research Assistants       0.00      0.00      0.00         1
#          Web Creations       1.00      1.00      1.00         2
#            Web Studios       1.00      1.00      1.00         1
#
#               accuracy                           0.86        73
#              macro avg       0.74      0.79      0.76        73
#           weighted avg       0.81      0.86      0.83        73
#
# Company Name Classification Report for fold 4:
#                          precision    recall  f1-score   support
#
#               AI Ethics       1.00      1.00      1.00         1
#          AI Innovations       1.00      1.00      1.00         2
#            Biz Analysts       0.00      0.00      0.00         1
#         Blockchain Tech       1.00      1.00      1.00         2
#                     CED       1.00      1.00      1.00         3
#          Cloud Analysts       1.00      1.00      1.00         2
#       Cloud Innovations       1.00      1.00      1.00         1
#        Cloud Innovators       1.00      1.00      1.00         1
#           Cloud Support       1.00      1.00      1.00         1
#            CodeCrafters       0.00      0.00      0.00         1
#      Compliance Experts       1.00      1.00      1.00         2
#  Compliance Specialists       0.00      0.00      0.00         1
# Cybersecurity Engineers       1.00      1.00      1.00         1
#          Data Engineers       1.00      1.00      1.00         2
#           Data Insights       1.00      1.00      1.00         3
#         Data Management       1.00      1.00      1.00         1
#           Data Managers       1.00      1.00      1.00         2
#            Data Privacy       1.00      1.00      1.00         1
#                 Databiz       0.00      0.00      0.00         0
#          Design Studios       1.00      1.00      1.00         1
#             Dev Interns       0.00      0.00      0.00         0
#        DevOps Solutions       0.50      1.00      0.67         1
#             IT Analysts       0.50      1.00      0.67         2
#          IT Consultancy       0.00      0.00      0.00         1
#          IT Consultants       0.00      0.00      0.00         1
#      IT Governance Mgmt       1.00      1.00      1.00         1
#             IT Services       0.00      0.00      0.00         1
#      IT Support Experts       1.00      1.00      1.00         1
#  IT Support Specialists       0.50      1.00      0.67         1
#             IT Training       0.50      1.00      0.67         1
# IT Training Specialists       0.00      0.00      0.00         1
#             Mobile Devs       1.00      1.00      1.00         1
#         Network Experts       1.00      1.00      1.00         1
#                OCTASOFT       1.00      1.00      1.00         2
#               ProcureIT       1.00      1.00      1.00         1
#    Procurement Analysts       0.00      0.00      0.00         1
#        Procurement Mgmt       1.00      1.00      1.00         1
#    Project Coordinators       1.00      1.00      1.00         1
#         Project Leaders       1.00      1.00      1.00         1
#             Purecontrol       1.00      0.67      0.80         3
#             QA Analysts       1.00      1.00      1.00         2
#            QA Solutions       1.00      1.00      1.00         2
#           Sales Leaders       0.50      1.00      0.67         1
#              Sales Reps       0.00      0.00      0.00         1
#             SecureCloud       1.00      1.00      1.00         1
#             SecureGuard       1.00      1.00      1.00         1
#                SecureIT       0.50      1.00      0.67         1
#            Service Desk       0.00      0.00      0.00         1
#     Software Architects       1.00      1.00      1.00         2
#        Tech Innovations       0.00      0.00      0.00         1
#          Tech Solutions       1.00      1.00      1.00         1
#          UX Innovations       0.50      1.00      0.67         1
#                 UX Labs       1.00      1.00      1.00         1
#           Web Creations       1.00      1.00      1.00         3
#             Web Studios       1.00      1.00      1.00         2
#
#                accuracy                           0.84        73
#               macro avg       0.70      0.76      0.72        73
#            weighted avg       0.79      0.84      0.80        73
#
# Company Name Classification Report for fold 5:
#                           precision    recall  f1-score   support
#
#                AI Ethics       1.00      1.00      1.00         2
#           AI Innovations       1.00      1.00      1.00         2
#           Asset Managers       0.00      0.00      0.00         0
#             Biz Analysts       0.00      0.00      0.00         1
#          Blockchain Tech       1.00      1.00      1.00         2
#                      CED       0.75      1.00      0.86         3
#           Cloud Analysts       1.00      1.00      1.00         2
#        Cloud Innovations       0.50      1.00      0.67         1
#          Cloud Migrators       0.00      0.00      0.00         1
#           Cloud Security       0.00      0.00      0.00         1
#            Cloud Support       1.00      1.00      1.00         1
#       Compliance Experts       1.00      1.00      1.00         2
#  Cybersecurity Engineers       1.00      1.00      1.00         1
#           Data Engineers       1.00      1.00      1.00         1
#            Data Insights       1.00      0.67      0.80         3
#             Data Interns       0.00      0.00      0.00         0
#          Data Management       1.00      1.00      1.00         1
#            Data Managers       1.00      1.00      1.00         1
#             Data Privacy       1.00      1.00      1.00         1
#                  Databiz       0.00      0.00      0.00         1
#           Design Studios       1.00      1.00      1.00         1
#              Dev Interns       0.00      0.00      0.00         1
#         DevOps Solutions       1.00      1.00      1.00         1
#              IT Analysts       0.50      1.00      0.67         1
#           IT Consultancy       1.00      1.00      1.00         1
#           IT Consultants       0.00      0.00      0.00         0
#       IT Governance Mgmt       1.00      1.00      1.00         1
#              IT Insights       0.00      0.00      0.00         1
#              IT Services       0.00      0.00      0.00         1
#             IT Solutions       1.00      1.00      1.00         1
#       IT Support Experts       0.50      1.00      0.67         1
#   IT Support Specialists       0.00      0.00      0.00         1
#              IT Training       0.50      1.00      0.67         1
#       IT Training Assist       0.00      0.00      0.00         1
#             ML Engineers       0.00      0.00      0.00         1
#              Mobile Devs       1.00      1.00      1.00         1
#          Network Experts       1.00      1.00      1.00         1
#                 OCTASOFT       1.00      1.00      1.00         2
#                ProcureIT       1.00      1.00      1.00         1
# Procurement Coordinators       0.00      0.00      0.00         0
#         Procurement Mgmt       1.00      1.00      1.00         1
#     Project Coordinators       0.00      0.00      0.00         2
#          Project Leaders       1.00      1.00      1.00         1
#              Purecontrol       1.00      1.00      1.00         3
#              QA Analysts       1.00      1.00      1.00         1
#             QA Solutions       1.00      1.00      1.00         2
#            Risk Analysts       1.00      1.00      1.00         1
#            Sales Leaders       1.00      1.00      1.00         1
#            Secure DevOps       0.50      1.00      0.67         1
#              SecureCloud       1.00      1.00      1.00         2
#              SecureGuard       1.00      1.00      1.00         2
#                 SecureIT       0.00      0.00      0.00         0
#      Software Architects       1.00      1.00      1.00         2
#           Tech Solutions       1.00      1.00      1.00         1
#             UX Designers       0.50      1.00      0.67         1
#           UX Innovations       0.00      0.00      0.00         1
#                  UX Labs       1.00      1.00      1.00         1
#            Web Creations       1.00      1.00      1.00         3
#              Web Studios       1.00      1.00      1.00         1
#
#                 accuracy                           0.81        73
#                macro avg       0.66      0.71      0.67        73
#             weighted avg       0.77      0.81      0.78        73
#
# Company Name final model saved to company_name_FFFfinalmodel.pkl

# %%
# Example of extracting job title and company name from a new job description text
new_text = """
Senior Front-end Angular Developer
•	CED
•	Tunis, Tunisie

Postes vacants:
1 poste ouvert
Type d'emploi désiré :
CDI
Experience :
3 à 5 ans
Niveau d'étude :
Ingénieur
Langue :
Français, Anglais
Genre :
Indifférent
Description de l'emploi
CED Group is an European service provider for many insurers, property managers, corporates and governments. Its business consists on protecting and restoring value for the citizens all over 14 European countries. 2000+ employees and experts are serving our customers all over Europe. CED Tunisia is a subsidiary of CED Group. It consists of an IT-BI Development center and a Businees Process Operations (BPO) team to support our various European offices and drive operational excellence. We employ 110 professionals as of now and going to recruit 20 new positions in the coming 3 months, 5 of them in IT. We are building in Tunis the digitalisation of all our front office applications and part of our middle office. Our solutions are in a Full Stack Environment using the most recent Microsoft Technologies: Angular, C#, .Net, SQL Server databases and Azure Cloud Technology.
We are reinforcing our team by recruiting a Senior Front-end Angular Developer who is passionate about design and programming. Responsibilities include implementing visual elements and their behaviors with user interactions. You will work with both front-end and back-end web developers to build all client-side logic. You will also be bridging the gap between the visual elements and the server-side infrastructure, taking an active role on both sides, and defining how the application looks and functions.

"""

# Predict the job title and company name from the new text
job_title_prediction = job_title_model.predict([new_text])
company_name_prediction = company_name_model.predict([new_text])

print(f"Predicted Job Title: {job_title_prediction[0]}")
print(f"Predicted Company Name: {company_name_prediction[0]}")
# Out:
# Predicted Job Title: Senior Front-end Angular Developer
# Predicted Company Name: CED
